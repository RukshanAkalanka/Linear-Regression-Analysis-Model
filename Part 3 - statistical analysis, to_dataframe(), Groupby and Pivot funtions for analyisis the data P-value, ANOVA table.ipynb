# %% [markdown]
#  <h3>Learn describe() function for statistical analysis, to_dataframe(), Groupby and Pivot funtions for analyisis the data</h3>
#  <h3>P-value/Pearson value, ANOVA table </h3>

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("preprocessed Auto_vehicle.csv")
df.head(20)
# Out:
#     symboling  normalized-losses         make aspiration num-of-doors  \
# 0           3                122  alfa-romero        std          two
# 1           3                122  alfa-romero        std          two
# 2           1                122  alfa-romero        std          two
# 3           2                164         audi        std         four
# 4           2                164         audi        std         four
# 5           2                122         audi        std          two
# 6           1                158         audi        std         four
# 7           1                122         audi        std         four
# 8           1                158         audi      turbo         four
# 9           2                192          bmw        std          two
# 10          0                192          bmw        std         four
# 11          0                188          bmw        std          two
# ...

# %%
#Descriptive Statistical Analysis
#The describe() function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.

df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean     0.899108  2555.666667   126.875622    3.330692    3.256874
# std      0.040933   517.296727    41.546834    0.268072    0.316048
# ...

# %%
#categorical varibles discribe
df.describe(include=["object"]) # all categorical varible datatype is object
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                201
# unique                 3
# top                  low
# freq                 153

# %%
#get the summery of categorical and numberical value both
df.describe(include="all")
# Out:
#          symboling  normalized-losses    make aspiration num-of-doors  \
# count   201.000000          201.00000     201        201          201
# unique         NaN                NaN      22          2            2
# top            NaN                NaN  toyota        std         four
# freq           NaN                NaN      32        165          115
# mean      0.840796          122.00000     NaN        NaN          NaN
# std       1.254802           31.99625     NaN        NaN          NaN
# min      -2.000000           65.00000     NaN        NaN          NaN
# 25%       0.000000          101.00000     NaN        NaN          NaN
# 50%       1.000000          122.00000     NaN        NaN          NaN
# 75%       2.000000          137.00000     NaN        NaN          NaN
# max       3.000000          256.00000     NaN        NaN          NaN
#
#        body-style drive-wheels engine-location  wheel-base      length  ...  \
# ...

# %%
#pandas value_counts( ) method use for identify unique values in columns
df["engine-location"].value_counts()
# Out:
# front    198
# rear       3
# Name: engine-location, dtype: int64

# %%
#now we want to put that value into dataframe
engine_loc_value_count= df["engine-location"].value_counts().to_frame()
engine_loc_value_count
# Out:
#        engine-location
# front              198
# rear                 3

# %%
#rename dataframe column name to value count
engine_loc_value_count.rename(columns={"engine-location":"value-count"}, inplace=True)
#and change index column as engine-location
engine_loc_value_count.index.name= "engine-location"

engine_loc_value_count
# Out:
#                  value-count
# engine-location
# front                    198
# rear                       3

# %%
#basic theory of grouping
# we want to get different "drive-wheels" vehiclas average price. for that we want to get all the vehichle price in different drive-wheels vehicls seperatly
# and get the mean price value of the each drive-wheels type

df["drive-wheels"].value_counts()
df["drive-wheels"].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one= df[["drive-wheels","price"]] # get two columns to seperate dataframe
df_group_one
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 2            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# ..           ...      ...
# 196          rwd  16845.0
# 197          rwd  19045.0
# 198          rwd  21485.0
# 199          rwd  22470.0
# 200          rwd  22625.0
#
# [201 rows x 2 columns]

# %%
df_group_one= df_group_one.groupby(["drive-wheels"], as_index=False).mean() #if as_index=False not give system get  "drive-wheels" columns by defult as index file
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
#finding the average price of vehicles and observe how they differ between different types of body styles and drive wheels variables
df_group_two= df[["drive-wheels","body-style","price"]]
df_group_two= df_group_two.groupby(["drive-wheels","body-style"], as_index=False).mean()
df_group_two
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
#for visualization, We can convert the dataframe to a pivot table using the method "pivot" to create a pivot table from the groups.\
grouped_pivot= df_group_two.pivot(index="drive-wheels", columns="body-style")
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
#NaN value fill by 0
grouped_pivot= grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# # Pearson correlation/ P-value
#
# pearson correlation mean measure of the extent of interdependence between variables
# ( measures the linear dependence between two variables X and Y.)
#
# + : possitive relationship(strong), ~0 : no relationship, - : negative relationship
#
# we can use method corr()
#
# calculating p values we need to use  "stats" module in the "scipy" library.

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008153           0.055045    0.158018  0.123952
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#calculate correlation and p value for  horsepower vs price 

pearson_coef, p_value= stats.pearsonr(df["horsepower"], df["price"])
print("The pearson correlation coefficient is : ", pearson_coef, "with p-value= ",p_value) # that p-vale <0.01 that mean 99% evidance to correct that relationship
# Out:
# The pearson correlation coefficient is :  0.809574567003656 with p-value=  6.369057428259557e-48

# %%
#calculate correlation and p value for engine-size vs price
pearson_coef, p_value= stats.pearsonr(df["engine-size"], df["price"])
print("The pearson correlation coefficient is : ", pearson_coef, "with p-value= ",p_value) # that p-vale <0.01 that mean 99% evidance to correct that relationship
# Out:
# The pearson correlation coefficient is :  0.8723351674455185 with p-value=  9.265491622198389e-64

# %%
# calculate correlation and p vlaue for highway-mpg vs price
pearson_coef, p_value= stats.pearsonr(df["highway-mpg"], df["price"])
print("The pearson correlation coefficient is : ", pearson_coef, "with p-value= ",p_value)
# Out:
# The pearson correlation coefficient is :  -0.7046922650589529 with p-value=  1.7495471144477352e-31

# %%
#you can see negative correlation that mean increase milage per galum price is decrese . below boxplot illusrate that relationship clearly
plt.figure(figsize=(15,5))
sns.boxenplot(x="make", y="price", data=df)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.boxenplot(x="highway-mpg", y="price", data=df)
plt.show()

# %% [markdown]
# # ANOVA table
# The Analysis of Variance (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:
#
# F-test score: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.
#
# P-value: P-value tells how statistically significant is our calculated score value.
#
# If our price variable is strongly correlated with the variable we are analyzing, expect ANOVA to return a sizeable F-test score and a small p-value.
#
# To analyze categorical variables such as the make variable, we can use a method such as the ANOVA method. ANOVA can be used to find the correlation between different groups of a categorical variable. According to the car dataset, we can use ANOVA to see if there is any difference in mean price for the different car makes such a Subaru and Honda. The ANOVA test returns two values, the F-test score and the p-value. The F-test calculates the ratio of variation between the groups mean over the variation within each of the sample groups. The p-value shows whether the obtained result is statistically significant. Without going too deep into the details, the F-test calculates the ratio of variation between groups means over the variation within each of the sample group means.
#
# (අපි හිතනවා drive-wheel column එකේ තියන groups(2wl front ,4wl,2wl rear) 3නේ price වල mean එක same. groups අනුව price එකේ වෙනසක් වෙන්නේ නැ කියල assume කරනවා.ANOVA එකෙන් ටෙස්ට් කරනව අපි හිතපු එක හරිද වැරදිද කියලා.

# %% [markdown]
# Drive Wheels
#
# Since ANOVA analyzes the difference between different groups of the same variable, the groupby function will come in handy. Because the ANOVA algorithm averages the data automatically, we do not need to take the average before hand.
#
# Let's see if different types 'drive-wheels' impact 'price', we group the data.

# %%
df_gptest= df[["drive-wheels", "price"]]
df_gptest.head()
# Out:
#   drive-wheels    price
# 0          rwd  13495.0
# 1          rwd  16500.0
# 2          rwd  16500.0
# 3          fwd  13950.0
# 4          4wd  17450.0

# %%
#price accoding to drive wheel group
price_grouped_drive_wheels= df_gptest.groupby(["drive-wheels"]) #in here we put .mean() that show mean price values only 3 groups we impliment same thing ambove cell
price_grouped_drive_wheels.head()
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 2            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 6            fwd  17710.0
# 7            fwd  18920.0
# 8            fwd  23875.0
# 9            rwd  16430.0
# 10           rwd  16925.0
# 136          4wd   7603.0
# 140          4wd   9233.0
# 141          4wd  11259.0
# 144          4wd   8013.0

# %%
price_grouped_drive_wheels.get_group("4wd")["price"]
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
from IPython.display import Image
Image("anova.JPG")

# %% [markdown]
# MSB : VARIANCE BETWEEN group means
# MSW : means of the within groups variance

# %%
#calculate anova table manually for 4wd and fwd groups

n1= price_grouped_drive_wheels.get_group("4wd")["price"].shape[0] #get number of car count for 4wd group that count come from .shape[0] method
n2= price_grouped_drive_wheels.get_group("fwd")["price"].shape[0]

y1bar= price_grouped_drive_wheels.get_group("4wd")["price"].mean()
y2bar= price_grouped_drive_wheels.get_group("fwd")["price"].mean() 
ybar= (sum(price_grouped_drive_wheels.get_group("4wd")["price"].values)+sum(price_grouped_drive_wheels.get_group("fwd")["price"].values))/(n1+n2)

SSB= n1*(y1bar-ybar)**2+n2*(y2bar-ybar)**2
MSB= SSB/(2-1)

sqr1= sum((price_grouped_drive_wheels.get_group("4wd")["price"].values)**2)
sqr2= sum((price_grouped_drive_wheels.get_group("4wd")["price"].values)**2)

SSW= sqr1+sqr2
MSW= SSW/(n1+n2-2)

F= MSB/ MSW
F
# Out:
# 0.5039878403398272

# %%
#calculate anova table manually for 4wd and rwd groups

n1= price_grouped_drive_wheels.get_group("4wd")["price"].shape[0] #get number of car count for 4wd group that count come from .shape[0] method
n2= price_grouped_drive_wheels.get_group("rwd")["price"].shape[0]

y1bar= price_grouped_drive_wheels.get_group("4wd")["price"].mean()
y2bar= price_grouped_drive_wheels.get_group("rwd")["price"].mean() 
ybar= (sum(price_grouped_drive_wheels.get_group("4wd")["price"].values)+sum(price_grouped_drive_wheels.get_group("rwd")["price"].values))/(n1+n2)

SSB= n1*(y1bar-ybar)**2+n2*(y2bar-ybar)**2
MSB= SSB/(2-1)

sqr1= sum((price_grouped_drive_wheels.get_group("4wd")["price"].values)**2)
sqr2= sum((price_grouped_drive_wheels.get_group("rwd")["price"].values)**2)

SSW= sqr1+sqr2
MSW= SSW/(n1+n2-2)

F= MSB/ MSW
F
# Out:
# 1.4610290156273547

# %%
#above F score value and P value can be calculate easly using sipy library
from scipy import stats
f_val, P_val= stats.f_oneway(price_grouped_drive_wheels.get_group("fwd")["price"], price_grouped_drive_wheels.get_group("rwd")["price"], price_grouped_drive_wheels.get_group("4wd")["price"])
print("ANOVA Result : F= ", f_val, ", P= ",P_val)
# Out:
# ANOVA Result : F=  67.95406500780399 , P=  3.3945443577151245e-23

# %% [markdown]
# This is a great result, with a large F test score showing a strong correlation and a P value of almost 0 implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated?

# %% [markdown]
# now we chack each two groups how relationship

# %%
#fwd and rwd
f_val, p_val= stats.f_oneway(price_grouped_drive_wheels.get_group("fwd")["price"],price_grouped_drive_wheels.get_group("rwd")["price"])
print("ANOVA Result between fwd and rwd groups : F= ", f_val, ", P= ",p_val)
# Out:
# ANOVA Result between fwd and rwd groups : F=  130.5533160959111 , P=  2.2355306355677845e-23

# %%
#4wd and fwd
f_val, p_val= stats.f_oneway(price_grouped_drive_wheels.get_group("4wd")["price"],price_grouped_drive_wheels.get_group("fwd")["price"])
print("ANOVA Result between 4wd and fwd groups : F= ", f_val, ", P= ",p_val)
# Out:
# ANOVA Result between 4wd and fwd groups : F=  0.665465750252303 , P=  0.41620116697845666

# %% [markdown]
# above #4wd and fwd result we can see f value is very small and p value is > 0.05 that mean test not significant
# ekiyanne api methana front wheel drive and 4wl drive group athe mean eka equal kiyala assume karapu eka true kiyanna bea.

# %%
#4wd and rwd
f_val, p_val= stats.f_oneway(price_grouped_drive_wheels.get_group("4wd")["price"],price_grouped_drive_wheels.get_group("rwd")["price"])
print("ANOVA Result between 4wd and rwd groups : F= ", f_val, ", P= ",p_val)
# Out:
# ANOVA Result between 4wd and rwd groups : F=  8.580681368924756 , P=  0.004411492211225333

# %%
#mea kiyana differance eka apita boxplot eken kalin pennuwa wage pennana puluwan
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxenplot(x="drive-wheels", y="price", data=df)
plt.show()

# %% [markdown]
# here you can see fwd and 4wd drive group no big difference of price. so that can see in anove table thar f score and p value is low
# but rwd vs 4wd and  rwd vs fwd groups has clear differance with price

# %% [markdown]
# # Conclusion: Important Variables

# %% [markdown]
# We now have a better idea of what our data looks like and which variables are important to take into account when predicting the car price. We have narrowed it down to the following variables:
#
# Continuous numerical variables:
#
# Length
# Width
# Curb-weight
# Engine-size
# Horsepower
# City-mpg
# Highway-mpg
# Wheel-base
# Bore
# Categorical variables:
# using anova table above we can see
# Drive-wheels varible
#
# As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.
